# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df[["Age", "Survived"]]
# Out:
#       Age  Survived
# 0    22.0         0
# 1    38.0         1
# 2    26.0         1
# 3    35.0         1
# 4    35.0         0
# ..    ...       ...
# 886  27.0         0
# 887  19.0         1
# 888   NaN         0
# 889  26.0         1
# 890  32.0         0
#
# [891 rows x 2 columns]

# %%
df[["Age", "Survived"]].describe()
# Out:
#               Age    Survived
# count  714.000000  891.000000
# mean    29.699118    0.383838
# std     14.526497    0.486592
# min      0.420000    0.000000
# 25%     20.125000    0.000000
# 50%     28.000000    0.000000
# 75%     38.000000    1.000000
# max     80.000000    1.000000

# %%
df[["Age", "Survived"]].head(100)
# Out:
#      Age  Survived
# 0   22.0         0
# 1   38.0         1
# 2   26.0         1
# 3   35.0         1
# 4   35.0         0
# ..   ...       ...
# 95   NaN         0
# 96  71.0         0
# 97  23.0         1
# 98  34.0         1
# 99  34.0         0
#
# [100 rows x 2 columns]

# %%
df.iloc[20:40]["Age"]
# Out:
# 20    35.0
# 21    34.0
# 22    15.0
# 23    28.0
# 24     8.0
# 25    38.0
# 26     NaN
# 27    19.0
# 28     NaN
# 29     NaN
# 30    40.0
# 31     NaN
# 32     NaN
# 33    66.0
# 34    28.0
# 35    42.0
# 36     NaN
# 37    21.0
# 38    18.0
# 39    14.0
# Name: Age, dtype: float64

# %%
df.iloc[20:40]
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# ...

# %%
df["Age"].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
df["Age"] * 2
# Out:
# 0      44.0
# 1      76.0
# 2      52.0
# 3      70.0
# 4      70.0
#        ...
# 886    54.0
# 887    38.0
# 888     NaN
# 889    52.0
# 890    64.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Age * 2"] = df["Age"] * 2
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[["Age * 2"] + list(df.columns)[:-1]]
# Out:
#      Age * 2  PassengerId
# 0       44.0            1
# 1       76.0            2
# 2       52.0            3
# 3       70.0            4
# 4       70.0            5
# ..       ...          ...
# 886     54.0          887
# 887     38.0          888
# 888      NaN          889
# 889     52.0          890
# 890     64.0          891
#
# [891 rows x 2 columns]

# %%
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Age * 2'],
#       dtype=object)

# %%
df[df["Survived"] == 0] # Filtre
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[df["Survived"] == 0].iloc[0:10]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 16           17         0       3
# 18           19         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# ...

# %%
df[(df["Survived"] == 0) & (df["Age"] > 20)]["Age"].hist()

# %%
df["Age"].hist()

# %%
# Afficher la distribution des ages pour les survivants
df[df["Survived"] == 1]["Age"].hist(bins=10)

# %%
# df2 = df[df['Survived']==0]
# df2[df2['Sex']=='female']0
len(df[(df["Survived"] == 0) & (df["Age"] > 20)]) / len(df[df["Age"] > 20])
# Out:
# 0.611214953271028

# %%
p_f = len(df[(df["Survived"] == 1) & (df["Sex"] == "female")]) / len(df[df["Sex"] == "female"])
p_h = len(df[(df["Survived"] == 1) & (df["Sex"] == "male")]) / len(df[df["Sex"] == "male"])
print(f"Pourcentage des femmes qui ont survécu {p_f * 100}%")
print(f"Pourcentage des hommes qui ont survécu {p_h * 100}%")
# Out:
# Pourcentage des femmes qui ont survécu 74.20382165605095%
# Pourcentage des hommes qui ont survécu 18.890814558058924%

# %%
df[(df["Survived"] == 1) & (df["Sex"] == "female")]["Age"].hist(alpha=0.5)
df[(df["Survived"] == 1) & (df["Sex"] == "male")]["Age"].hist(alpha=0.5)

# %%
df.to_excel("mon_fichier.xls")

# %%
help(df.to_excel)
# Out:
# Help on method to_excel in module pandas.core.generic:
#
# to_excel(excel_writer, sheet_name='Sheet1', na_rep='', float_format=None, columns=None, header=True, index=True, index_label=None, startrow=0, startcol=0, engine=None, merge_cells=True, encoding=None, inf_rep='inf', verbose=True, freeze_panes=None) -> None method of pandas.core.frame.DataFrame instance
#     Write object to an Excel sheet.
#
#     To write a single object to an Excel .xlsx file it is only necessary to
#     specify a target file name. To write to multiple sheets it is necessary to
#     create an `ExcelWriter` object with a target file name, and specify a sheet
#     in the file to write to.
#
#     Multiple sheets may be written to by specifying unique `sheet_name`.
#     With all data written to the file it is necessary to save the changes.
#     Note that creating an `ExcelWriter` object with a file name that already
#     exists will result in the contents of the existing file being erased.
#
# ...

# %%
df.plot("Age", "Fare")

# %%
df.plot.scatter("Age", "Fare")

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# Age * 2        714
# dtype: int64

# %%
df2 = df.drop(columns=["Cabin", "Age * 2"])

# %%
df2.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Embarked       889
# dtype: int64

# %%
df3 = df2.dropna()
df3.count()
# Out:
# PassengerId    712
# Survived       712
# Pclass         712
# Name           712
# Sex            712
# Age            712
# SibSp          712
# Parch          712
# Ticket         712
# Fare           712
# Embarked       712
# dtype: int64

# %%
df["Age"].mean()
df["Age"].median()
# Out:
# 28.0

# %%
df3.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df3["Embarked"] = df3["Embarked"].map({"S": 0, "C": 1, "Q": 2})
df3.head()
# Out:
# C:\Users\miguel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
# Transformer la colone Sex en 0 ou 1
df3["Sex"] = df3.Sex.map({"male": 0, "female": 1})
# Out:
# C:\Users\miguel\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %% [markdown]
# ## Expression régulière

# %%
import re

print(re.match("GR.?S", "GRAS"))
print(re.findall("[0-9]+", "J'habite au 28 rue Marcel Proust"))
print(re.findall("[0-9a-zA-Z]+", "J'habite au 28 rue Marcel Proust"))
print(re.findall("[^ b]+", "J'habite au 28 rue Marcel Proust"))
# Out:
# <re.Match object; span=(0, 4), match='GRAS'>
# ['28']
# ['J', 'habite', 'au', '28', 'rue', 'Marcel', 'Proust']
# ["J'ha", 'ite', 'au', '28', 'rue', 'Marcel', 'Proust']

# %%
print(re.findall("\d{10}", "J'habite au 28 rue Marcel Proust. Mon numéro est 0689845753"))
# Out:
# ['0689845753']

# %%
print(re.sub("\d{10}", "XXX","J'habite au 28 rue Marcel Proust. Mon numéro est 0689845753"))
# Out:
# J'habite au 28 rue Marcel Proust. Mon numéro est XXX

# %%
# Récupérer xx.xx.xx.xx.xx
print(re.findall("\d{2}\.\d{2}\.\d{2}\.\d{2}\.\d{2}", "J'habite au 28 rue Marcel Proust. Mon numéro est 06.89.84.57.53"))
# Out:
# ['06.89.84.57.53']

# %%
resultat = re.findall("((\d{2}\.){4}\d{2})", "J'habite au 28 rue Marcel Proust. Mon numéro est 06.89.84.57.53")
num = [i[0] for i in resultat]

# %%
num
# Out:
# ['06.89.84.57.53']

# %% [markdown]
# ## Retour sur la conversion des titres et des tickets

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
import re

def convert_ticket(raw_ticket):
    try:
        res = re.findall("\d+$", raw_ticket)
        return res[0]
    except:
        print(raw_ticket)
        return -1

# %%
df3.Ticket = df3.Ticket.map(convert_ticket)
# Out:
# LINE
# LINE
# LINE
# LINE
# C:\Users\miguel\Anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df3 = df3[df3.Ticket != -1]

# %%
df3.count()
# Out:
# PassengerId    708
# Survived       708
# Pclass         708
# Name           708
# Sex            708
# Age            708
# SibSp          708
# Parch          708
# Ticket         708
# Fare           708
# Embarked       708
# dtype: int64

# %%
import re

def convert_title(raw_title):
    try:
        res = re.findall(", ([^.]*)\.", raw_title)
        return res[0]
    except:
        print(raw_ticket)
        return -1

# %%
df3["Title"] = df3.Name.map(convert_title)
# Out:
# C:\Users\miguel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df3.Title.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer'], dtype=object)

# %%
df3.to_excel("Titanic.xls")
